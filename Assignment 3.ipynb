# %% [markdown]
# # Imports

# %%
import psycopg2
import psycopg2.extras

import pandas as pd

# %% [markdown]
# # Section A: Getting Data by kaggle API

# %% [markdown]
# ## A.1 First we need to add our kaggle.jason file (extracted from kaggle account) to our computer directory.

# %%
# %cd 
#!mkdir ~/.kaggle
#!mv kaggle.json ~/.kaggle
# Out:
# C:\Users\kjama

# %% [markdown]
# ## A.2 Reviewing Covid related dataset from kaggle

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
# !kaggle datasets list -s "Covid"
# Out:
# ref                                                title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# imdevskp/corona-virus-report                       COVID-19 Dataset                                     19MB  2020-08-07 03:47:47         181844       1535  1.0
# sudalairajkumar/covid19-in-india                   COVID-19 in India                                   758KB  2021-08-11 04:14:10         147742       1740  0.9117647
# gpreda/covid-world-vaccination-progress            COVID-19 World Vaccination Progress                   2MB  2022-02-10 18:23:57          75476       1995  1.0
# roche-data-science-coalition/uncover               UNCOVER COVID-19 Challenge                          258MB  2021-10-31 00:04:09          21454       1280  0.875
# tawsifurrahman/covid19-radiography-database        COVID-19 Radiography Database                       745MB  2021-03-06 18:17:46          41415        638  0.9375
# andrewmvd/covid19-ct-scans                         COVID-19 CT scans                                     1GB  2020-04-23 12:29:33          14359        481  1.0
# sudalairajkumar/covid19-in-usa                     COVID-19 in USA                                      10MB  2020-12-07 06:23:33          21381        279  0.9705882
# sudalairajkumar/covid19-in-italy                   COVID-19 in Italy                                   441KB  2020-12-07 06:23:24          15343        236  1.0
# iamhungundji/covid19-symptoms-checker              COVID-19 Symptoms Checker                           912KB  2020-03-21 06:05:59          12961        199  1.0
# hendratno/covid19-indonesia                        COVID-19 Indonesia Dataset                          902KB  2021-12-04 01:59:45          12873        197  1.0
# allen-institute-for-ai/CORD-19-research-challenge  COVID-19 Open Research Dataset Challenge (CORD-19)   14GB  2022-02-02 21:02:08         139036       9779  0.88235295
# bachrr/covid-chest-xray                            COVID-19 chest xray                                 241MB  2020-05-15 00:30:50           9300        214  0.9411765
# mariaren/covid19-healthy-diet-dataset              COVID-19 Healthy Diet Dataset                        82KB  2021-02-07 21:50:53          14909        371  1.0
# atilamadai/covid19                                 COVID-19                                            281MB  2022-02-13 07:04:45           1931         42  0.88235295
# kaushiksuresh147/covidvaccine-tweets               Covid Vaccine Tweets                                 59MB  2022-02-10 09:50:16           2791         68  1.0
# tunguz/covid19-genomes                             COVID-19 Genomes                                    405KB  2021-06-17 19:59:48           1051         78  1.0
# fireballbyedimyrnmom/us-counties-covid-19-dataset  US counties COVID 19 dataset                         24MB  2022-02-12 22:04:53          17780        411  0.9411765
# anandhuh/latest-covid19-india-statewise-data       Latest Covid-19 India Statewise Data                  1KB  2022-02-13 16:41:17          19562        687  1.0
# lalish99/covid19-mx                                COVID-19 MX                                          13MB  2020-07-24 03:43:20           1912         65  1.0
# gpreda/all-covid19-vaccines-tweets                 COVID-19 All Vaccines Tweets                         30MB  2021-11-23 21:07:45           6452        204  1.0

# %% [markdown]
# ## 3 Downloading data

# %%
api.dataset_download_files('imdevskp/corona-virus-report',unzip=True)

# %%
Covid_set_name="country_wise_latest.csv"
data=pd.read_csv(Covid_set_name)
data.head(5)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %% [markdown]
# #  Section B: Fixing data Columns for PostgreSQL queries synatx

# %% [markdown]
# ## B.1 Replacing signs  ( `~!@#$%^&*)(-+=,.?/\|  ) with underscore (_)

# %%
modfied_columns={}
for column_I in data.columns:
    new_column=column_I
    for operations in " `~!@#$%^&*)(-+=,.?/\|":
        new_column=new_column.replace(operations, "_")
    modfied_columns[column_I]=new_column
data.rename(columns = modfied_columns,inplace = True)
data.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  New_deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  1_week_change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1_week___increase             WHO_Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %% [markdown]
# ## B.2 Adding Underscore (_) before number starting columns

# %%
modfied_columns2={}
for column_I in data.columns:
    first_char=column_I[0]
    if first_char in "0123456789":
        first_char= "_" + first_char
        new_column=first_char + column_I[1:]     
        modfied_columns2[column_I]=new_column
data.rename(columns = modfied_columns2,inplace = True)
data.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  New_deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  _1_week_change  \
# 0                    5.04                35526             737
# 1                    5.25                 4171             709
# 2                    6.17                23691            4282
# 3                    6.48                  884              23
# 4                   16.94                  749             201
#
#    _1_week___increase             WHO_Region
# 0                2.07  Eastern Mediterranean
# 1               17.00                 Europe
# 2               18.07                 Africa
# 3                2.60                 Europe
# 4               26.84                 Africa

# %% [markdown]
# ## B.3 outputing ready dataset for copying into PostgreSQL

# %%
data.to_csv('sqldata.csv',index=False)
sql_data=pd.read_csv('sqldata.csv')
sql_data.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered  Active  New_cases  New_deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New_recovered  Deaths___100_Cases  Recovered___100_Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths___100_Recovered  Confirmed_last_week  _1_week_change  \
# 0                    5.04                35526             737
# 1                    5.25                 4171             709
# 2                    6.17                23691            4282
# 3                    6.48                  884              23
# 4                   16.94                  749             201
#
#    _1_week___increase             WHO_Region
# 0                2.07  Eastern Mediterranean
# 1               17.00                 Europe
# 2               18.07                 Africa
# 3                2.60                 Europe
# 4               26.84                 Africa

# %% [markdown]
# # SectionC: Copying data into PosgreSQL

# %% [markdown]
# ## C1. Building automatic query for : Create table

# %%
def Create_table_query(data,Table_name,PK_index=0):
    Ptype_adjustment={"<class 'str'>":"varchar" ,
                  "<class 'numpy.int64'>":"int","<class 'int'>":"int",
                  "<class 'numpy.float64'>":"float(24)","<class 'float'>":"float(24)" }

    query=f'Create Table {Table_name} ({data.columns[PK_index]} {Ptype_adjustment[str(type(data.iloc[0,PK_index]))]} PRIMARY KEY,'
    for index,value in enumerate(data.columns):
        if index != PK_index:
            query=f'{query} {data.columns[index]} {Ptype_adjustment[str(type(data.iloc[0,index]))]},'


    new_query = list(query)
    new_query[-1] = ')'
    new_query=''.join(new_query)
    new_query=new_query +";"
    new_query
    return new_query

Create_table_query(data,"covid_set",0)
# Out:
# 'Create Table covid_set (Country_Region varchar PRIMARY KEY, Confirmed int, Deaths int, Recovered int, Active int, New_cases int, New_deaths int, New_recovered int, Deaths___100_Cases float(24), Recovered___100_Cases float(24), Deaths___100_Recovered float(24), Confirmed_last_week int, _1_week_change int, _1_week___increase float(24), WHO_Region varchar);'

# %% [markdown]
# ## C2. Building automatic query for : Copy table

# %%
def Create_Copy_Query(Path,Table_name):
    dataset=pd.read_csv(Path)
    headings=','.join(list(dataset.columns))
    newquery2= "COPY "+ Table_name+"(" + headings +") From " + "'" +Path + "'" + "DELIMITER ','" + "CSV HEADER;"
    return newquery2
Create_Copy_Query('C:/Mine/Ph.D/Semester 2/Intro to big data/Assignments/2022_GGE6505_AS03/sqldata.csv',"Covid_set")
# Out:
# "COPY Covid_set(Country_Region,Confirmed,Deaths,Recovered,Active,New_cases,New_deaths,New_recovered,Deaths___100_Cases,Recovered___100_Cases,Deaths___100_Recovered,Confirmed_last_week,_1_week_change,_1_week___increase,WHO_Region) From 'C:/Mine/Ph.D/Semester 2/Intro to big data/Assignments/2022_GGE6505_AS03/sqldata.csv'DELIMITER ','CSV HEADER;"

# %% [markdown]
# ## C.3 Copying data into PostgreSQL

# %%
def Copy_to_SQL(Path,Table_name,PK_index=0):
    #Initialization
    conn = psycopg2.connect(database="GGE6505_AS03",user='postgres', password="Baran2620352738",host="localhost", port='5432')
    conn.autocommit = True
    cursor = conn.cursor()
    # reading data into dataframe
    dataset=pd.read_csv(Path)
    # creating table
    SQL_Create_table = Create_table_query(data,Table_name,PK_index)
    cursor.execute(SQL_Create_table)
    # Copy table
    SQL_Copy_table = Create_Copy_Query(Path,Table_name)
    cursor.execute(SQL_Copy_table)
    #Finalization
    conn.commit()
    conn.close()

Copy_to_SQL(Path='C:/Mine/Ph.D/Semester 2/Intro to big data/Assignments/2022_GGE6505_AS03/sqldata.csv',
            Table_name="mytbl2",
            PK_index=0)

# %% [markdown]
# ## C.4 Query_execution

# %%
def Execute_Query(SQL):
    #Initialization
    conn = psycopg2.connect(database="GGE6505_AS03",user='postgres', password="Baran2620352738",host="localhost", port='5432')
    conn.autocommit = True
    cursor = conn.cursor()
    
    cursor.execute(SQL)
    colnames = [desc[0] for desc in cursor.description]
    df=pd.DataFrame(columns= colnames)
    for i in cursor.fetchall():
        to_append = list(i)
        df_length = len(df)
        df.loc[df_length] = to_append
          
    #Finalization
    conn.commit()
    conn.close()
    return df

# %%
SQL="Select * From mytbl Where Confirmed > 2000000"
Execute_Query(SQL)
# Out:
#   country_region confirmed  deaths recovered   active new_cases new_deaths  \
# 0         Brazil   2442375   87618   1846641   508116     23284        614
# 1             US   4290259  148011   1325804  2816444     56336       1076
#
#   new_recovered  deaths___100_cases  recovered___100_cases  \
# 0         33728                3.59                  75.61
# 1         27941                3.45                  30.90
#
#    deaths___100_recovered confirmed_last_week _1_week_change  \
# 0                    4.74             2118646         323729
# 1                   11.16             3834677         455582
#
#    _1_week___increase who_region
# 0               15.28   Americas
# 1               11.88   Americas

# %% [markdown]
# # EnD
